# %%
import torch
print(torch.cuda.is_available())  # True nếu GPU đã sẵn sàng
print(torch.cuda.get_device_name(0))  # Tên GPU
# Out:
# True
# NVIDIA GeForce RTX 2050

# %%
# !pip install "numpy<2"
# Out:
# ...
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.8 MB 2.1 MB/s eta 0:00:08
#    -- ------------------------------------- 1.0/15.8 MB 2.3 MB/s eta 0:00:07
#    --- ------------------------------------ 1.6/15.8 MB 2.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.8/15.8 MB 2.3 MB/s eta 0:00:07
#    ------ --------------------------------- 2.6/15.8 MB 2.4 MB/s eta 0:00:06
#    ------- -------------------------------- 2.9/15.8 MB 2.3 MB/s eta 0:00:06
#    -------- ------------------------------- 3.4/15.8 MB 2.2 MB/s eta 0:00:06
#    --------- ------------------------------ 3.7/15.8 MB 2.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 4.5/15.8 MB 2.3 MB/s eta 0:00:05
# ...

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from collections import defaultdict
import torch

# Kiểm tra GPU
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU device: {torch.cuda.get_device_name(0)}")

# Khởi tạo model trên GPU
model = YOLO('yolov9s.pt').to('cuda:0')

CLASS_ID = 0  # ID lớp 'person'
CONF_THRESHOLD = 0.5

zone_points = []
zone_ready = False
current_in_zone = set()
track_history = defaultdict(list)

def draw_zone(event, x, y, flags, param):
    global zone_points, zone_ready
    if event == cv2.EVENT_LBUTTONDOWN and not zone_ready:
        zone_points.append((x, y))
        print(f"Point {len(zone_points)}: ({x}, {y})")
        if len(zone_points) == 5:
            zone_ready = True
            print("Zone is ready!")

cap = cv2.VideoCapture('C:/Users/ACER/Downloads/DAT/Test.mp4')
cv2.namedWindow('Zone People Counter')
cv2.setMouseCallback('Zone People Counter', draw_zone)

while cap.isOpened():
    success, frame = cap.read()
    if not success:
        break

    # Vẽ các điểm đã chọn
    for i, point in enumerate(zone_points):
        cv2.circle(frame, point, 8, (0, 255, 0), -1)
        cv2.putText(frame, str(i+1), (point[0]+10, point[1]-10), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)

    # Vẽ đa giác khi đã đủ 5 điểm
    if zone_ready:
        pts = np.array(zone_points, np.int32)
        pts = pts.reshape((-1, 1, 2))
        cv2.polylines(frame, [pts], isClosed=True, color=(0, 255, 0), thickness=2)

    # Nhận diện và theo dõi đối tượng
    results = model.track(
        source=frame,
        classes=[CLASS_ID],
        conf=CONF_THRESHOLD
    )

    # Kiểm tra đối tượng trong vùng
    current_frame_ids = set()
    if results[0].boxes.id is not None and zone_ready:
        boxes = results[0].boxes.xywh.cpu().numpy()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        for box, track_id in zip(boxes, track_ids):
            x, y, w, h = box
            center = (int(x), int(y))
            # Kiểm tra điểm tâm có nằm trong vùng zone
            if cv2.pointPolygonTest(pts, center, False) >= 0:
                current_frame_ids.add(track_id)
                cv2.rectangle(frame, 
                             (int(x - w/2), int(y - h/2)),
                             (int(x + w/2), int(y + h/2)),
                             (0, 0, 255), 2)
                track_history[track_id].append(center)
                if len(track_history[track_id]) > 30:
                    track_history[track_id].pop(0)

    current_in_zone = current_frame_ids

    cv2.putText(frame, f'In Zone: {len(current_in_zone)}', (10, 30), 
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.putText(frame, "Click 5 points for zone", (10, 70), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)
    cv2.putText(frame, "Press 'r' to reset zone", (10, 100), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

    for track_id, points in track_history.items():
        for i in range(1, len(points)):
            cv2.line(frame, points[i-1], points[i], (255, 0, 0), 2)

    cv2.imshow('Zone People Counter', frame)
    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):
        break
    elif key == ord('r'):
        zone_points = []
        zone_ready = False

cap.release()
cv2.destroyAllWindows()
# Out:
# PyTorch version: 2.3.1+cu121
# CUDA available: True
# GPU device: NVIDIA GeForce RTX 2050
#
# 0: 384x640 5 persons, 19.6ms
# Speed: 1.8ms preprocess, 19.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22.1ms
# Speed: 1.4ms preprocess, 22.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 18.4ms
# Speed: 1.4ms preprocess, 18.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 18.1ms
# Speed: 1.4ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 20.2ms
# Speed: 1.3ms preprocess, 20.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 18.1ms
# ...

# %%
# !pip list
# Out:
# Package            Version
# ------------------ ------------
# asttokens          3.0.0
# certifi            2025.1.31
# charset-normalizer 3.4.1
# click              8.1.8
# colorama           0.4.6
# comm               0.2.2
# contourpy          1.3.2
# cycler             0.12.1
# dataclasses        0.6
# debugpy            1.8.14
# decorator          5.2.1
# exceptiongroup     1.2.2
# executing          2.2.0
# filelock           3.17.0
# fonttools          4.58.4
# fsspec             2025.2.0
# huggingface-hub    0.29.2
# idna               3.10
# intel-openmp       2021.4.0
# ipykernel          6.29.5
# ipython            8.35.0
# jedi               0.19.2
# Jinja2             3.1.6
# joblib             1.4.2
# jupyter_client     8.6.3
# jupyter_core       5.7.2
# kiwisolver         1.4.8
# lap                0.5.12
# MarkupSafe         3.0.2
# matplotlib         3.10.3
# matplotlib-inline  0.1.7
# mkl                2021.4.0
# mpmath             1.3.0
# ...

# %%
pip install torch==2.3.1 torchvision==0.18.1 torchaudio==2.3.1 --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#   Using cached https://download.pytorch.org/whl/cu121/torch-2.3.1%2Bcu121-cp310-cp310-win_amd64.whl (2423.5 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/torchvision-0.18.1%2Bcu121-cp310-cp310-win_amd64.whl (5.7 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/torchaudio-2.3.1%2Bcu121-cp310-cp310-win_amd64.whl (4.1 MB)
# ...
#   Using cached https://download.pytorch.org/whl/mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# ...
#   Using cached https://download.pytorch.org/whl/intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# ...
#   Using cached https://download.pytorch.org/whl/tbb-2021.11.0-py3-none-win_amd64.whl (298 kB)
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu118
#     Can't uninstall 'torch'. No files were found to uninstall.
# ...
